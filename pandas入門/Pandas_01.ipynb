# %%
import pandas as pd

# %%
df_population_data = pd.read_csv('testdata_01.csv',encoding='utf-8')

# %%
df_population_data
# Out:
#    都道府県       平成22年       平成27年  人口増加率     平成30年想定  人口増減想定率
# 0    全国  128,057.00  127,095.00   -0.8  126,443.00     -2.1
# 1   北海道    5,506.00    5,382.00   -2.3    5,286.00     -6.5
# 2    青森    1,373.00    1,308.00   -4.7    1,263.00    -12.2
# 3    岩手    1,330.00    1,280.00   -3.8    1,241.00    -11.2
# 4    宮城    2,348.00    2,334.00   -0.6    2,316.00     -3.3
# 5    秋田    1,086.00    1,023.00   -5.8      981.00    -14.7
# 6    山形    1,169.00    1,124.00   -3.9    1,090.00    -10.4
# 7    福島    2,029.00    1,914.00   -5.7    1,864.00     -9.9
# 8    茨城    2,970.00    2,917.00   -1.8    2,877.00     -5.2
# 9    栃木    2,008.00    1,974.00   -1.7    1,946.00     -5.6
# 10   群馬    2,008.00    1,973.00   -1.7    1,952.00     -3.9
# 11   埼玉    7,195.00    7,267.00    1.0    7,330.00      2.8
# 12   千葉    6,216.00    6,223.00    0.1    6,255.00      1.4
# 13   東京   13,159.00   13,515.00    2.7   13,822.00      7.2
# 14  神奈川    9,048.00    9,126.00    0.9    9,177.00      2.0
# ...

# %%
type(df_population_data)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_rows',2) #最大表示行数のオプション

# %%
df_population_data
# Out:
#    都道府県    平成22年    平成27年  人口増加率  平成30年想定  人口増減想定率
# 0    全国  128,057  127,095   -0.8  126,443     -2.1
# ..  ...      ...      ...    ...      ...      ...
# 47   沖縄    1,393    1,434    2.9    1,448      3.1
#
# [48 rows x 6 columns]

# %%
pd.reset_option('display.max_rows') #リセット

# %%
pd.set_option('display.max_columns',5) #最大表示列数のオプション

# %%
df_population_data
# Out:
#    都道府県    平成22年  ...  平成30年想定  人口増減想定率
# 0    全国  128,057  ...  126,443     -2.1
# 1   北海道    5,506  ...    5,286     -6.5
# 2    青森    1,373  ...    1,263    -12.2
# 3    岩手    1,330  ...    1,241    -11.2
# 4    宮城    2,348  ...    2,316     -3.3
# 5    秋田    1,086  ...      981    -14.7
# 6    山形    1,169  ...    1,090    -10.4
# 7    福島    2,029  ...    1,864     -9.9
# 8    茨城    2,970  ...    2,877     -5.2
# 9    栃木    2,008  ...    1,946     -5.6
# 10   群馬    2,008  ...    1,952     -3.9
# 11   埼玉    7,195  ...    7,330      2.8
# 12   千葉    6,216  ...    6,255      1.4
# 13   東京   13,159  ...   13,822      7.2
# 14  神奈川    9,048  ...    9,177      2.0
# 15   新潟    2,374  ...    2,246     -9.2
# 16   富山    1,093  ...    1,050     -5.2
# 17   石川    1,170  ...    1,143     -3.5
# 18   福井      806  ...      774     -5.9
# 19   山梨      863  ...      817     -7.1
# 20   長野    2,152  ...    2,063     -6.0
# 21   岐阜    2,081  ...    1,997     -5.8
# ...

# %%
pd.reset_option('display.max_columns') #リセット

# %%
df_population_data
# Out:
#    都道府県    平成22年    平成27年  人口増加率  平成30年想定  人口増減想定率
# 0    全国  128,057  127,095   -0.8  126,443     -2.1
# 1   北海道    5,506    5,382   -2.3    5,286     -6.5
# 2    青森    1,373    1,308   -4.7    1,263    -12.2
# 3    岩手    1,330    1,280   -3.8    1,241    -11.2
# 4    宮城    2,348    2,334   -0.6    2,316     -3.3
# 5    秋田    1,086    1,023   -5.8      981    -14.7
# 6    山形    1,169    1,124   -3.9    1,090    -10.4
# 7    福島    2,029    1,914   -5.7    1,864     -9.9
# 8    茨城    2,970    2,917   -1.8    2,877     -5.2
# 9    栃木    2,008    1,974   -1.7    1,946     -5.6
# 10   群馬    2,008    1,973   -1.7    1,952     -3.9
# 11   埼玉    7,195    7,267    1.0    7,330      2.8
# 12   千葉    6,216    6,223    0.1    6,255      1.4
# 13   東京   13,159   13,515    2.7   13,822      7.2
# 14  神奈川    9,048    9,126    0.9    9,177      2.0
# 15   新潟    2,374    2,304   -3.0    2,246     -9.2
# 16   富山    1,093    1,066   -2.5    1,050     -5.2
# ...

# %%
df_population_data.head()
# Out:
#   都道府県    平成22年    平成27年  人口増加率  平成30年想定  人口増減想定率
# 0   全国  128,057  127,095   -0.8  126,443     -2.1
# 1  北海道    5,506    5,382   -2.3    5,286     -6.5
# 2   青森    1,373    1,308   -4.7    1,263    -12.2
# 3   岩手    1,330    1,280   -3.8    1,241    -11.2
# 4   宮城    2,348    2,334   -0.6    2,316     -3.3

# %%
df_population_data.head(10)
# Out:
#   都道府県    平成22年    平成27年  人口増加率  平成30年想定  人口増減想定率
# 0   全国  128,057  127,095   -0.8  126,443     -2.1
# 1  北海道    5,506    5,382   -2.3    5,286     -6.5
# 2   青森    1,373    1,308   -4.7    1,263    -12.2
# 3   岩手    1,330    1,280   -3.8    1,241    -11.2
# 4   宮城    2,348    2,334   -0.6    2,316     -3.3
# 5   秋田    1,086    1,023   -5.8      981    -14.7
# 6   山形    1,169    1,124   -3.9    1,090    -10.4
# 7   福島    2,029    1,914   -5.7    1,864     -9.9
# 8   茨城    2,970    2,917   -1.8    2,877     -5.2
# 9   栃木    2,008    1,974   -1.7    1,946     -5.6

# %%
df_population_data.tail(10)
# Out:
#    都道府県  平成22年  平成27年  人口増加率 平成30年想定  人口増減想定率
# 38   愛媛  1,431  1,385   -3.2   1,352     -9.0
# 39   高知    764    728   -4.7     706    -10.6
# 40   福岡  5,072  5,102    0.6   5,107      0.1
# 41   佐賀    850    833   -2.0     819     -5.5
# 42   長崎  1,427  1,377   -3.5   1,341     -9.9
# 43   熊本  1,817  1,786   -1.7   1,757     -4.8
# 44   大分  1,197  1,166   -2.5   1,144     -7.5
# 45   宮崎  1,135  1,104   -2.7   1,081     -7.4
# 46  鹿児島  1,706  1,648   -3.4   1,614     -7.0
# 47   沖縄  1,393  1,434    2.9   1,448      3.1

# %%
df_population_data.sample(10)
# Out:
#    都道府県    平成22年    平成27年  人口増加率  平成30年想定  人口増減想定率
# 46  鹿児島    1,706    1,648   -3.4    1,614     -7.0
# 12   千葉    6,216    6,223    0.1    6,255      1.4
# 40   福岡    5,072    5,102    0.6    5,107      0.1
# 13   東京   13,159   13,515    2.7   13,822      7.2
# 0    全国  128,057  127,095   -0.8  126,443     -2.1
# 9    栃木    2,008    1,974   -1.7    1,946     -5.6
# 37   香川      996      976   -2.0      962     -5.6
# 39   高知      764      728   -4.7      706    -10.6
# 41   佐賀      850      833   -2.0      819     -5.5
# 15   新潟    2,374    2,304   -3.0    2,246     -9.2

# %%
df_population_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   都道府県     48 non-null     object
#  1   平成22年    48 non-null     object
#  2   平成27年    48 non-null     object
#  3   人口増加率    48 non-null     float64
#  4   平成30年想定  48 non-null     object
#  5   人口増減想定率  48 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 2.4+ KB

# %%
df_population_data.describe()
# Out:
#            人口増加率    人口増減想定率
# count  48.000000  48.000000
# mean   -1.950000  -5.291667
# std     1.902518   4.460791
# min    -5.800000 -14.700000
# 25%    -3.200000  -8.550000
# 50%    -2.200000  -5.600000
# 75%    -0.950000  -3.375000
# max     2.900000   7.200000

# %%
df_population_data.describe().round(0)
# Out:
#        人口増加率  人口増減想定率
# count   48.0     48.0
# mean    -2.0     -5.0
# std      2.0      4.0
# min     -6.0    -15.0
# 25%     -3.0     -9.0
# 50%     -2.0     -6.0
# 75%     -1.0     -3.0
# max      3.0      7.0
