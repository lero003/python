# %%
import pandas as pd

# %%
url = 'https://finance.yahoo.com/quote/AAPL/history?p=AAPL&.tsrc=fin-srch'

# %%
data = pd.read_html(url, header = 0)

# %%
data[0].head()
# Out:
#            Date    Open    High     Low  Close* Adj Close**    Volume
# 0  Jun 10, 2020  347.90  354.77  346.09  352.84      352.84  41509200
# 1  Jun 09, 2020  332.14  345.61  332.01  343.99      343.99  36928100
# 2  Jun 08, 2020  330.25  333.60  327.32  333.46      333.46  23913600
# 3  Jun 05, 2020  323.35  331.75  323.23  331.50      331.50  34312600
# 4  Jun 04, 2020  324.39  325.62  320.78  322.32      322.32  21890100

# %%
data[0].tail()
# Out:
#                                                   Date  \
# 96                                        Jan 27, 2020
# 97                                        Jan 24, 2020
# 98                                        Jan 23, 2020
# 99                                        Jan 22, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 96                                              310.06
# 97                                              320.25
# 98                                              317.92
# 99                                              318.58
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 96                                              311.77
# 97                                              323.33
# 98                                              319.56
# 99                                              319.99
# ...

# %%
data[0]
# Out:
#                                                   Date  \
# 0                                         Jun 10, 2020
# 1                                         Jun 09, 2020
# 2                                         Jun 08, 2020
# 3                                         Jun 05, 2020
# 4                                         Jun 04, 2020
# ..                                                 ...
# 96                                        Jan 27, 2020
# 97                                        Jan 24, 2020
# 98                                        Jan 23, 2020
# 99                                        Jan 22, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                               347.90
# 1                                               332.14
# 2                                               330.25
# 3                                               323.35
# ...

# %%
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-6226a73926db> in <module>
# ----> 1 data.dtypes
#
# AttributeError: 'list' object has no attribute 'dtypes'
