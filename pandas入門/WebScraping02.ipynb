# %%
import pandas as pd
df_list = pd.read_html("https://ja.wikipedia.org/wiki/%E8%BF%91%E4%BB%A3%E3%82%AA%E3%83%AA%E3%83%B3%E3%83%94%E3%83%83%E3%82%AF%E3%81%A7%E3%81%AE%E5%9B%BD%E3%83%BB%E5%9C%B0%E5%9F%9F%E5%88%A5%E3%83%A1%E3%83%80%E3%83%AB%E7%B7%8F%E7%8D%B2%E5%BE%97%E6%95%B0%E4%B8%80%E8%A6%A7")

# %%
print(type(df_list))
>>> <class 'list'>
# Out:
#   File "<ipython-input-7-c3a2b94cd6b8>", line 2
#     <class 'list'>
#     ^
# SyntaxError: invalid syntax

# %%
df_list[0]
# Out:
#                          国・地域  夏季参加回数     金     銀     銅     合計  冬季参加回数   金.1  \
# 0               アフガニスタン (AFG)      14     0     0     2      2       0     0
# 1                アルジェリア (ALG)      13     5     4     8     17       3     0
# 2                アルゼンチン (ARG)      24    21    25    28     74      19     0
# 3                 アルメニア (ARM)       6     2     6     6     14       7     0
# 4        オーストララシア (ANZ) [ANZ]       2     3     4     5     12       0     0
# ..                        ...     ...   ...   ...   ...    ...     ...   ...
# 148          独立参加 (IOA) [IOA]       3     1     0     1      2       0     0
# 149          独立参加 (IOP) [IOP]       1     0     1     2      3       0     0
# 150  ロシアからのオリンピック (OAR) [OAR]       0     0     0     0      0       1     2
# 151         混合チーム (ZZX) [ZZX]       3     8     5     4     17       0     0
# 152                        合計      28  5115  5080  5482  15677      23  1060
#
#       銀.1   銅.1  合計.1  参加回数   金.2   銀.2   銅.2     総数
# 0       0     0     0    14     0     0     2      2
# 1       0     0     0    16     5     4     8     17
# 2       0     0     0    43    21    25    28     74
# 3       0     0     0    13     2     6     6     14
# 4       0     0     0     2     3     4     5     12
# ..    ...   ...   ...   ...   ...   ...   ...    ...
# 148     0     0     0     3     1     0     1      2
# 149     0     0     0     1     0     1     2      3
# 150     6     9    17     1     2     6     9     17
# 151     0     0     0     3     8     5     4     17
# 152  1058  1050  3168    51  6175  6138  6532  18845
#
# [153 rows x 16 columns]
